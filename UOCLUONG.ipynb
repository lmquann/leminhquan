# %% [markdown]
# <a href="https://colab.research.google.com/github/lmquann/leminhquan/blob/main/UOCLUONG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import scipy.stats as st
from math import sqrt

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Nhập dữ liệu: 
sample = [11.5, 11.5, 11.5, 11.5, 11.5,
        11.6, 11.6, 11.6, 11.6, 11.6, 11.6, 11.6, 11.6,
        11.7, 11.7, 11.7, 11.7,
        11.8, 11.8, 11.8, 11.8, 11.8, 11.8,
        11.9,
        12]
st.norm.interval(alpha=0.95, loc=np.mean(sample), scale=st.sem(sample))
# Out:
# (11.61830032506553, 11.725699674934468)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Nhập dữ liệu:
sample = [11.5, 11.5, 11.5, 11.5, 11.5,
        11.6, 11.6, 11.6, 11.6, 11.6, 11.6, 11.6, 11.6,
        11.7, 11.7, 11.7, 11.7,
        11.8, 11.8, 11.8, 11.8, 11.8, 11.8,
        11.9,
        12]
#Giải: 
st.t.interval(alpha=0.95, df=len(sample)-1, loc=np.mean(sample), scale=st.sem(sample))
# Out:
# (11.615452694676348, 11.72854730532365)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
s8 = st.norm.ppf((1 - 0.95)/2)
alpha = .05
n = 0.2
print("cỡ mẫu tối thiểu phải lấy là: ", ((s8/alpha * n)**2)+1)
# Out:
# cỡ mẫu tối thiểu phải lấy là:  62.463341131106006

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Nhập dữ liệu:
s9 = [11.5, 11.5, 11.5, 11.5, 11.5,
        11.6, 11.6, 11.6, 11.6, 11.6, 11.6, 11.6, 11.6,
        11.7, 11.7, 11.7, 11.7,
        11.8, 11.8, 11.8, 11.8, 11.8, 11.8,
        11.9,
        12]
t = st.t.ppf((1 - 0.95)/2, df=25 - 1)
alpha = .05 
n = np.std(s9, ddof = 1)
print("cỡ mẫu tối thiểu phải lấy là: ", ((t/alpha * n)**2)+1)
# Out:
# cỡ mẫu tối thiểu phải lấy là:  32.97597739366131

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
var = .0153
t = st.t.ppf(1 - 0.95, df = 20 - 1)
print("ước lượng khoảng tối đa: ", (var * df)/t)
# Out:
# ước lượng khoảng tối đa:  -0.16811895423130013
