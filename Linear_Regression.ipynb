# %% [markdown]
# <a href="https://colab.research.google.com/github/lmquann/leminhquan/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. Tổng quan cơ sở toán học**

# %% [markdown]
# *   Bài toán hồi quy

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *   Hàm mất mát

# %% [markdown]
# Hàm mất mát được xây dựng dựa vào mong muốn giá trị thực và giá trị đầu ra có độ lệch nhỏ nhất

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Sử dụng bình phương để dễ đạo hàm và độ lệch thì không âm để không bị triệt tiêu khi tính tổng độ lệch
#
#
# Nguyên nhân cho việc chia 2 ở công thức trên:
#
#
# *   Không ảnh hưởng đến việc tìm giá trị cực tiểu của J(w)
#
# *   Khi đạo hàm thì sẽ bị triệt tiêu đi
#
# Tìm w sao cho J(w) min hay

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *   Gradient Decent

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *   Normal Equation: Mặc dù tính chính xác nhưng vì phép nghịch đảo (khá hữu dụng trong lý thuyết) nhưng trên thực tế cần chi phí tính toán cao nên với tập dữ liệu lớn nhiều feature người ta thường dùng Gradient Descent và các biến thể

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **2. Cài đặt thuật toán**

# %% [markdown]
# Thực hành với bộ dữ liệu data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt
import math
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import accuracy_score

# %% [markdown]
# Hồi quy đơn biến

# %%
data  = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/data.csv")
D= np.array(data)
D = preprocessing.MinMaxScaler().fit_transform(D)
X, y = D[:,0], D[:,-1]
X = np.array(X) #đưa X và y về dạng ma trận
y=np.array(y)
X = X.reshape(-1, 1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=30)

# %%
plt.scatter(X_train, y_train)
plt.xlabel('trục X')
plt.ylabel('Trục Y')
plt.title('Biểu đồ dữ liệu X và y')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression().fit(X_train, y_train)
y_hat = model.predict(X_test)

# %%
mse=mean_squared_error(y_test, y_hat)
print('Mean Squared Error (MSE):', mse)
rmse = np.sqrt(mean_squared_error(y_test, y_hat))
print('Root Mean Squared Error (RMSE):', rmse)
r2 = r2_score(y_test, y_hat)
print('R-squared (R^2):', r2)
mae = mean_absolute_error(y_test, y_hat)
print("Mean Absolute Error (MAE):", mae)

# %% [markdown]
# **Kết luận**
#
# Với Mean Squared Error (MSE) có giá trị là 0.014835250217975693, chúng ta có thể kết luận rằng mô hình có một tổng sai số bình phương trung bình nhỏ. MSE tính toán sự khác biệt bình phương trung bình giữa các giá trị dự đoán và giá trị thực tế, và giá trị càng nhỏ thể hiện một mô hình có khả năng dự đoán chính xác cao hơn.
#
# Tóm lại, MSE thấp chỉ ra rằng mô hình có khả năng dự đoán chính xác cao hơn, nhưng cần kết hợp với các thông tin khác và so sánh với độ đo khác để đánh giá toàn diện về hiệu suất.

# %% [markdown]
# **Hồi quy đa biến**

# %%
data  = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/data.csv")
D = np.array(data)
D = preprocessing.MinMaxScaler().fit_transform(D)
X, y = D[:,:-1], D[:,-1]
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.20,random_state=15)

# %%
model = linear_model.LinearRegression().fit(X_train, y_train)
print("trọng sô tối ưu : w_1 = ", model.coef_[0], "bias = ", model.intercept_)

y_hat = model.predict(X_test)

# %%
fig, ax = plt.subplots()
# ax.plot(X, y)
plt.scatter(X[:,0], y, color='red')
plt.scatter(X[:,1], y, color='yellow')

ax.set_title("Biểu đồ đường")
ax.set_xlabel("Trục X")
ax.set_ylabel("Trục Y")

plt.show()

# %%
mse=mean_squared_error(y_test, y_hat)
print('Mean Squared Error (MSE):', mse)
rmse = np.sqrt(mean_squared_error(y_test, y_hat))
print('Root Mean Squared Error (RMSE):', rmse)
r2 = r2_score(y_test, y_hat)
print('R-squared (R^2):', r2)
mae = mean_absolute_error(y_test, y_hat)
print("Mean Absolute Error (MAE):", mae)

# %% [markdown]
# **Kết luận**
#
# MSE đo lường độ lớn của sai số trung bình giữa dự đoán và giá trị thực tế. Giá trị MSE nhỏ hơn 1 chỉ ra rằng mô hình có khả năng dự đoán chính xác. Trong trường hợp này, MSE gần 0.01 cho thấy rằng mô hình có khả năng dự đoán tương đối tốt.
