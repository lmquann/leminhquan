# %% [markdown]
# <a href="https://colab.research.google.com/github/lmquann/leminhquan/blob/main/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import minmax_scale
from sklearn.linear_model import LinearRegression
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def readData(folder, filename): #Hàm đọc dữ liệu từ tập tin 
    data = np.loadtxt(os.path.join(folder, filename), delimiter=',')
    print('Original data shape', data.shape)
    X = data[:,0]
    print('X shape: ', X.shape)
    y = data[:,1]
    print('y shape: ', y.shape)
    m = y.shape[0]
    print('Number of training examples m = ', m)
    X = np.stack([np.ones(m), X], axis=1)
    print('Modified X shape: ', X.shape)
    return X, y
def computeLoss(X, y, w): #Hàm mất mát
    m = y.shape[0]
    J = 0
    h = np.dot(X, w)
    J = (1/(2*m))*np.sum(np.square(h - y))
    return J
def gradientDescent(X, y, w, alpha, n):
    m = y.shape[0]
    J_history = []
    w_optimal = w.copy()
    print('w_optimal shape: ', w_optimal.shape)
    for i in range(n):
        w_optimal = w_optimal - (alpha/m)*(np.dot(X, w_optimal) - y).dot(X)
        J_history.append(computeLoss(X, y, w_optimal))
    return w_optimal, J_history
def main():
    w = np.zeros(2)
    n = 1500
    alpha = 0.01
    X, y = readData("/content/drive/MyDrive/học máy 1", "ex1data1.txt")
    X[:,1:] = minmax_scale(X[:,1:], axis = 0)
    y = minmax_scale(y, axis = 0)
    print(X, y)
    model = LinearRegression()
    model.fit(X,y)
    print('\t\tw optimal: ', model.coef_)
    w, J_history = gradientDescent(X, y, w, alpha, n)
    print("w_optimal:", w.T)

if __name__ == '__main__':
    main()
# Out:
# Original data shape (97, 2)
# X shape:  (97,)
# y shape:  (97,)
# Number of training examples m =  97
# Modified X shape:  (97, 2)
# [[1.00000000e+00 6.30643743e-02]
#  [1.00000000e+00 2.91567935e-02]
#  [1.00000000e+00 2.03288290e-01]
#  [1.00000000e+00 1.15061044e-01]
#  [1.00000000e+00 4.84917997e-02]
#  [1.00000000e+00 1.95387777e-01]
#  [1.00000000e+00 1.42610954e-01]
#  [1.00000000e+00 2.06752406e-01]
#  [1.00000000e+00 8.49610796e-02]
#  [1.00000000e+00 1.61270603e-03]
#  [1.00000000e+00 3.98111329e-02]
#  [1.00000000e+00 5.31965929e-01]
#  [1.00000000e+00 4.11676690e-02]
#  [1.00000000e+00 1.96872398e-01]
#  [1.00000000e+00 3.57357025e-02]
#  [1.00000000e+00 2.05227031e-02]
#  [1.00000000e+00 7.79280512e-02]
#  [1.00000000e+00 6.00834881e-03]
#  [1.00000000e+00 8.16658031e-02]
#  [1.00000000e+00 1.18996745e-01]
#  [1.00000000e+00 6.76637886e-02]
#  [1.00000000e+00 8.87459901e-01]
#  [1.00000000e+00 2.69677051e-02]
#  [1.00000000e+00 7.56399881e-02]
#  [1.00000000e+00 3.13225936e-02]
#  [1.00000000e+00 8.10317825e-01]
#  [1.00000000e+00 4.54183429e-01]
#  [1.00000000e+00 3.45252997e-01]
#  [1.00000000e+00 4.74444140e-01]
#  [1.00000000e+00 1.00000000e+00]
#  [1.00000000e+00 1.31287079e-02]
#  [1.00000000e+00 9.09694284e-02]
#  [1.00000000e+00 2.45765919e-01]
#  [1.00000000e+00 5.03548535e-02]
#  [1.00000000e+00 1.85385507e-01]
#  [1.00000000e+00 1.69217692e-01]
#  [1.00000000e+00 1.78678513e-01]
#  [1.00000000e+00 3.37329196e-02]
#  [1.00000000e+00 4.54649193e-01]
#  [1.00000000e+00 7.72294060e-02]
#  [1.00000000e+00 2.21237650e-02]
#  [1.00000000e+00 1.08033838e-01]
#  [1.00000000e+00 3.88976543e-01]
#  [1.00000000e+00 4.34790203e-02]
